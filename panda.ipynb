# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\DHANVIN RANJITH\Downloads\archive\tested.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
data.describe().T
# Out:
#              count         mean         std     min       25%        50%  \
# PassengerId  418.0  1100.500000  120.810458  892.00  996.2500  1100.5000
# Survived     418.0     0.363636    0.481622    0.00    0.0000     0.0000
# Pclass       418.0     2.265550    0.841838    1.00    1.0000     3.0000
# Age          332.0    30.272590   14.181209    0.17   21.0000    27.0000
# SibSp        418.0     0.447368    0.896760    0.00    0.0000     0.0000
# Parch        418.0     0.392344    0.981429    0.00    0.0000     0.0000
# Fare         417.0    35.627188   55.907576    0.00    7.8958    14.4542
#
#                  75%        max
# PassengerId  1204.75  1309.0000
# Survived        1.00     1.0000
# Pclass          3.00     3.0000
# Age            39.00    76.0000
# SibSp           1.00     8.0000
# Parch           0.00     9.0000
# Fare           31.50   512.3292

# %%
data.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.dropna(inplace=True)

# %%
data.Survived
# Out:
# 12     1
# 14     1
# 24     1
# 26     1
# 28     0
#       ..
# 404    0
# 405    0
# 407    0
# 411    1
# 414    1
# Name: Survived, Length: 87, dtype: int64

# %%
data.Survived.head(15)
# Out:
# 12    1
# 14    1
# 24    1
# 26    1
# 28    0
# 34    0
# 44    1
# 46    0
# 48    1
# 50    0
# 53    1
# 57    0
# 59    1
# 64    0
# 68    0
# Name: Survived, dtype: int64

# %%
data.fillna(110,inplace=True)

# %%
data.fillna({"Survived":1},inplace=True)
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                            Brady, Mr. John Bertram    male  41.0      0
#
#     Parch       Ticket      Fare            Cabin Embarked
# 12      0        21228   82.2667              B45        S
# 14      0  W.E.P. 5734   61.1750              E31        S
# 24      3     PC 17608  262.3750  B57 B59 B63 B66        C
# 26      1       113509   61.9792              B36        C
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
m=data["Age"].mean()
print(m)
# Out:
# 30.272590361445783

# %%
data.drop("Cabin",axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.1+ KB

# %%
data.fillna({"Age":m},inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.1+ KB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Survived     417 non-null    int64
#  2   Pclass       417 non-null    int64
#  3   Name         417 non-null    object
#  4   Sex          417 non-null    object
#  5   Age          417 non-null    float64
#  6   SibSp        417 non-null    int64
#  7   Parch        417 non-null    int64
#  8   Ticket       417 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     417 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 39.1+ KB

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
survived = data[data['Survived']==1]
# Out:
# Sex
# female    152
# Name: count, dtype: int64

# %%
survived.Sex.value_counts()
# Out:
# Sex
# female    152
# Name: count, dtype: int64

# %%
data.Pclass.unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
data[['Pclass','Fare']].groupby(data.Pclass).mean()
# Out:
#         Pclass       Fare
# Pclass
# 1          1.0  94.280297
# 2          2.0  22.202104
# 3          3.0  12.459678

# %%
data[['Survived','Age']].groupby(data.Survived).mean()
# Out:
#           Survived        Age
# Survived
# 0              0.0  30.158634
# 1              1.0  30.272400

# %%
data.drop(['PassengerId','Ticket'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 0         0       3                              Kelly, Mr. James    male
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2         0       2                     Myles, Mr. Thomas Francis    male
# 3         0       3                              Wirz, Mr. Albert    male
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Embarked
# 0  34.5      0      0   7.8292        Q
# 1  47.0      1      0   7.0000        S
# 2  62.0      0      0   9.6875        Q
# 3  27.0      0      0   8.6625        S
# 4  22.0      1      1  12.2875        S

# %%
data.sample(5)
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 364         1       1  Harder, Mrs. George Achilles (Dorothy Annan)  female
# 216         1       3                    Mahon, Miss. Bridget Delia  female
# 166         0       1                            Brandeis, Mr. Emil    male
# 385         1       2                            Herman, Miss. Kate  female
# 102         0       3                            Foley, Mr. William    male
#
#           Age  SibSp  Parch     Fare Embarked
# 364  25.00000      1      0  55.4417        C
# 216  30.27259      0      0   7.8792        Q
# 166  48.00000      0      0  50.4958        C
# 385  24.00000      1      2  65.0000        S
# 102  30.27259      0      0   7.7500        Q

# %%
data[data.Embarked=='S']
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           0       3                    Svensson, Mr. Johan Cervin    male
# 7           0       2                  Caldwell, Mr. Albert Francis    male
# ..        ...     ...                                           ...     ...
# 409         1       3                     Peacock, Miss. Treasteall  female
# 412         1       3                Henriksson, Miss. Jenny Lovisa  female
# 413         0       3                            Spector, Mr. Woolf    male
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
#
#           Age  SibSp  Parch     Fare Embarked
# ...

# %%
data.Embarked.value_counts()
# Out:
# Embarked
# S    269
# C    102
# Q     46
# Name: count, dtype: int64

# %%
data.Sex[data["Sex"]=='female']=0
# Out:
# C:\Users\DHANVIN RANJITH\AppData\Local\Temp\ipykernel_22152\4086176432.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.Sex[data["Sex"]=='female']=0
# ...

# %%
data.loc[:,'Sex'][data["Sex"]=='female']=0
# Out:
# C:\Users\DHANVIN RANJITH\AppData\Local\Temp\ipykernel_22152\1159385681.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.loc[:,'Sex'][data["Sex"]=='female']=0
# ...

# %%
data.loc[:,'Sex'][data["Sex"]=='male']=1
# Out:
# C:\Users\DHANVIN RANJITH\AppData\Local\Temp\ipykernel_22152\3318402932.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.loc[:,'Sex'][data["Sex"]=='male']=1
# ...

# %%
data.Sex
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 413    1
# 414    0
# 415    1
# 416    1
# 417    1
# Name: Sex, Length: 417, dtype: object

# %%
data.loc[:,'Survived'][data["Survived"]=='S']='U'

# %%
data.loc[:,'Survived'][data["Survived"]==1]='S'

# %%
data.head()
# Out:
#   Survived  Pclass                                          Name Sex   Age  \
# 0        U       3                              Kelly, Mr. James   1  34.5
# 1        S       3              Wilkes, Mrs. James (Ellen Needs)   0  47.0
# 2        U       2                     Myles, Mr. Thomas Francis   1  62.0
# 3        U       3                              Wirz, Mr. Albert   1  27.0
# 4        S       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   0  22.0
#
#    SibSp  Parch     Fare Embarked
# 0      0      0   7.8292        Q
# 1      1      0   7.0000        S
# 2      0      0   9.6875        Q
# 3      0      0   8.6625        S
# 4      1      1  12.2875        S

# %%
data.Age.max()
# Out:
# 76.0

# %%
data.Age.min()
# Out:
# 0.17

# %%
dict1 = employee_data = {
    "Name": [
        "Alice Johnson",
        "Bob Williams",
        "Charlie Brown",
        "Diana Prince",
        "Eve Adams",
        "Frank White",
        "Grace Lee",
        "Henry Green",
        "Ivy Blue",
        "Jack Taylor",
        "Karen Miller",
        "Liam Davis"
    ],
    "Join_Date": [
        "2022-03-15",
        "2021-11-01",
        "2023-01-20",
        "2022-07-01",
        "2021-09-10",
        "2023-04-05",
        "2022-02-28",
        "2021-12-15",
        "2023-06-01",
        "2022-10-20",
        "2021-08-01",
        "2023-03-10"
    ]
}

# %%
dict1.keys()
# Out:
# dict_keys(['Name', 'Join_Date'])

# %%
data=pd.DataFrame(dict1)

# %%
data
# Out:
#              Name   Join_Date
# 0   Alice Johnson  2022-03-15
# 1    Bob Williams  2021-11-01
# 2   Charlie Brown  2023-01-20
# 3    Diana Prince  2022-07-01
# 4       Eve Adams  2021-09-10
# 5     Frank White  2023-04-05
# 6       Grace Lee  2022-02-28
# 7     Henry Green  2021-12-15
# 8        Ivy Blue  2023-06-01
# 9     Jack Taylor  2022-10-20
# 10   Karen Miller  2021-08-01
# 11     Liam Davis  2023-03-10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       12 non-null     object
#  1   Join_Date  12 non-null     object
# dtypes: object(2)
# memory usage: 324.0+ bytes

# %%
data.head()
# Out:
#             Name   Join_Date
# 0  Alice Johnson  2022-03-15
# 1   Bob Williams  2021-11-01
# 2  Charlie Brown  2023-01-20
# 3   Diana Prince  2022-07-01
# 4      Eve Adams  2021-09-10

# %%
data['Join_Date']=pd.to_datetime(data.Join_Date)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       12 non-null     object
#  1   Join_Date  12 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 324.0+ bytes

# %%
data
# Out:
#              Name  Join_Date
# 0   Alice Johnson 2022-03-15
# 1    Bob Williams 2021-11-01
# 2   Charlie Brown 2023-01-20
# 3    Diana Prince 2022-07-01
# 4       Eve Adams 2021-09-10
# 5     Frank White 2023-04-05
# 6       Grace Lee 2022-02-28
# 7     Henry Green 2021-12-15
# 8        Ivy Blue 2023-06-01
# 9     Jack Taylor 2022-10-20
# 10   Karen Miller 2021-08-01
# 11     Liam Davis 2023-03-10

# %%
data[data.Join_Date.dt.year==2021]
# Out:
#             Name  Join_Date
# 1   Bob Williams 2021-11-01
# 4      Eve Adams 2021-09-10
# 7    Henry Green 2021-12-15
# 10  Karen Miller 2021-08-01

# %%
data[data.Join_Date.dt.year==2023]
# Out:
#              Name  Join_Date
# 2   Charlie Brown 2023-01-20
# 5     Frank White 2023-04-05
# 8        Ivy Blue 2023-06-01
# 11     Liam Davis 2023-03-10

# %%
data[data.Join_Date.dt.month<=6]
# Out:
#              Name  Join_Date
# 0   Alice Johnson 2022-03-15
# 2   Charlie Brown 2023-01-20
# 5     Frank White 2023-04-05
# 6       Grace Lee 2022-02-28
# 8        Ivy Blue 2023-06-01
# 11     Liam Davis 2023-03-10

# %%
data['month']=data.Join_Date.dt.month

# %%
data.head()
# Out:
#             Name  Join_Date  month
# 0  Alice Johnson 2022-03-15      3
# 1   Bob Williams 2021-11-01     11
# 2  Charlie Brown 2023-01-20      1
# 3   Diana Prince 2022-07-01      7
# 4      Eve Adams 2021-09-10      9

# %%
data['year']=data.Join_Date.dt.year

# %%
data.head()
# Out:
#             Name  Join_Date  month  year
# 0  Alice Johnson 2022-03-15      3  2022
# 1   Bob Williams 2021-11-01     11  2021
# 2  Charlie Brown 2023-01-20      1  2023
# 3   Diana Prince 2022-07-01      7  2022
# 4      Eve Adams 2021-09-10      9  2021

# %%
data['date']=data.Join_Date.dt.date

# %%
data.head()
# Out:
#             Name  Join_Date  month  year        date
# 0  Alice Johnson 2022-03-15      3  2022  2022-03-15
# 1   Bob Williams 2021-11-01     11  2021  2021-11-01
# 2  Charlie Brown 2023-01-20      1  2023  2023-01-20
# 3   Diana Prince 2022-07-01      7  2022  2022-07-01
# 4      Eve Adams 2021-09-10      9  2021  2021-09-10

# %%
data['day']=data.Join_Date.dt.day

# %%
data.head()
# Out:
#             Name  Join_Date  month  year        date  day
# 0  Alice Johnson 2022-03-15      3  2022  2022-03-15   15
# 1   Bob Williams 2021-11-01     11  2021  2021-11-01    1
# 2  Charlie Brown 2023-01-20      1  2023  2023-01-20   20
# 3   Diana Prince 2022-07-01      7  2022  2022-07-01    1
# 4      Eve Adams 2021-09-10      9  2021  2021-09-10   10

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James   1  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)   0  47.0      1      0
# 2                     Myles, Mr. Thomas Francis   1  62.0      0      0
# 3                              Wirz, Mr. Albert   1  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   0  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
n_data=data[['Survived','Pclass','Age','Fare','Sex']]

# %%
n_data.corr()
# Out:
#           Survived    Pclass       Age      Fare       Sex
# Survived  1.000000 -0.108615 -0.000013  0.191514 -1.000000
# Pclass   -0.108615  1.000000 -0.492143 -0.577147  0.108615
# Age      -0.000013 -0.492143  1.000000  0.337932  0.000013
# Fare      0.191514 -0.577147  0.337932  1.000000 -0.191514
# Sex      -1.000000  0.108615  0.000013 -0.191514  1.000000

# %%
data['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>
